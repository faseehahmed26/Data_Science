# %% [markdown]
# # TimberMan Bot

# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# ^C

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (7.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipywidgets) (6.13.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipywidgets) (3.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipywidgets) (5.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipywidgets) (1.1.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipywidgets) (8.3.0)
# Requirement already satisfied: packaging in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: nest-asyncio in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.1)
# Requirement already satisfied: psutil in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.4.11)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.5.1)
# Requirement already satisfied: fastjsonschema in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.3)
# Requirement already satisfied: jupyter-core in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.10.0)
# Requirement already satisfied: decorator in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.12.0)
# Requirement already satisfied: pickleshare in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (49.2.1)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.4.4)
# Requirement already satisfied: backcall in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.8)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.3)
# Requirement already satisfied: argon2-cffi in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.0)
# Requirement already satisfied: prometheus-client in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.14.1)
# Requirement already satisfied: jinja2 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" and platform_python_implementation != "PyPy" in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (304)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.8.3)
# Requirement already satisfied: executing in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.2)
# Requirement already satisfied: wcwidth in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0; os_name == "nt" in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.1)
# Requirement already satisfied: bleach in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.0)
# Requirement already satisfied: tinycss2 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (3.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\moham\desktop\faseeh\odbot\odbot\scripts\python.exe -m pip install --upgrade pip' command.

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# !cd yolov5 & pip install -r requirements.txt --upgrade
# Out:
# Collecting matplotlib>=3.2.2
#   Using cached matplotlib-3.5.2-cp38-cp38-win_amd64.whl (7.2 MB)
# Collecting numpy>=1.18.5
#   Using cached numpy-1.22.3-cp38-cp38-win_amd64.whl (14.7 MB)
# Collecting opencv-python>=4.1.1
#   Using cached opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
# Collecting Pillow>=7.1.2
#   Using cached Pillow-9.1.0-cp38-cp38-win_amd64.whl (3.3 MB)
# Collecting PyYAML>=5.3.1
#   Using cached PyYAML-6.0-cp38-cp38-win_amd64.whl (155 kB)
# Collecting requests>=2.23.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.8.0-cp38-cp38-win_amd64.whl (36.9 MB)
# Collecting torch>=1.7.0
#   Downloading torch-1.11.0-cp38-cp38-win_amd64.whl (158.0 MB)
#      -------------------------------------- 158.0/158.0 MB 4.6 MB/s eta 0:00:00
# Collecting torchvision>=0.8.1
#   Downloading torchvision-0.12.0-cp38-cp38-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 6.5 MB/s eta 0:00:00
# Collecting tqdm>=4.41.0
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.9.0-py3-none-any.whl (5.8 MB)
#      ---------------------------------------- 5.8/5.8 MB 4.4 MB/s eta 0:00:00
# Collecting pandas>=1.1.4
#   Using cached pandas-1.4.2-cp38-cp38-win_amd64.whl (10.6 MB)
# Collecting seaborn>=0.11.0
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting thop
#   Downloading thop-0.0.31.post2005241907-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (21.3)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.2-cp38-cp38-win_amd64.whl (55 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.8)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.33.3-py3-none-any.whl (930 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: colorama in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.4)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting grpcio>=1.24.3
#   Using cached grpcio-1.46.0-cp38-cp38-win_amd64.whl (3.5 MB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.1.2-py3-none-any.whl (224 kB)
# Collecting wheel>=0.26
#   Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-3.20.1-cp38-cp38-win_amd64.whl (904 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (49.2.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: six in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.8.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, pytz, pyasn1, certifi, wheel, werkzeug, urllib3, typing-extensions, tqdm, tensorboard-data-server, rsa, PyYAML, pyasn1-modules, protobuf, Pillow, oauthlib, numpy, kiwisolver, importlib-metadata, idna, grpcio, fonttools, cycler, charset-normalizer, cachetools, absl-py, torch, scipy, requests, pandas, opencv-python, matplotlib, markdown, google-auth, torchvision, thop, seaborn, requests-oauthlib, google-auth-oauthlib, tensorboard
# Successfully installed Pillow-9.1.0 PyYAML-6.0 absl-py-1.0.0 cachetools-5.0.0 certifi-2021.10.8 charset-normalizer-2.0.12 cycler-0.11.0 fonttools-4.33.3 google-auth-2.6.6 google-auth-oauthlib-0.4.6 grpcio-1.46.0 idna-3.3 importlib-metadata-4.11.3 kiwisolver-1.4.2 markdown-3.3.7 matplotlib-3.5.2 numpy-1.22.3 oauthlib-3.2.0 opencv-python-4.5.5.64 pandas-1.4.2 protobuf-3.20.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pytz-2022.1 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.8 scipy-1.8.0 seaborn-0.11.2 tensorboard-2.9.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 thop-0.0.31.post2005241907 torch-1.11.0 torchvision-0.12.0 tqdm-4.64.0 typing-extensions-4.2.0 urllib3-1.26.9 werkzeug-2.1.2 wheel-0.37.1

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('yolov5', 'yolov5s', source='local')
# Out:
# YOLOv5  v6.1-177-gd059d1d torch 1.11.0+cpu CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Collecting torch==1.8.1+cu111
#   Downloading https://download.pytorch.org/whl/lts/1.8/cu111/torch-1.8.1%2Bcu111-cp38-cp38-win_amd64.whl (3055.7 MB)
#      --------                                 0.7/3.1 GB 2.8 MB/s eta 0:14:26
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\moham\AppData\Local\Programs\Python\Python38\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\moham\AppData\Local\Programs\Python\Python38\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\moham\AppData\Local\Programs\Python\Python38\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\moham\AppData\Local\Programs\Python\Python38\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\moham\AppData\Local\Programs\Python\Python38\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\cli\base_command.py", line 167, in exc_logging_wrapper
#     status = run_func(*args)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\cli\req_command.py", line 205, in wrapper
#     return func(self, options, args)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\commands\install.py", line 339, in run
#     requirement_set = resolver.resolve(
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 348, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 215, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 288, in __init__
#     super().__init__(
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 158, in __init__
#     self.dist = self._prepare()
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 299, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\operations\prepare.py", line 487, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\operations\prepare.py", line 532, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\operations\prepare.py", line 214, in unpack_url
#     file = get_http_url(
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\operations\prepare.py", line 94, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\network\download.py", line 146, in __call__
#     for chunk in chunks:
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\cli\progress_bars.py", line 304, in _rich_progress_bar
#     for chunk in iterable:
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\moham\AppData\Local\Programs\Python\Python38\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='download.pytorch.org', port=443): Read timed out.
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode=nearest)
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode=nearest)
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # 3. Make Detections with Images

# %%
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1142.5ms pre-process, 279.7ms inference, 15.1ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[72, 48, 38],
#          [74, 50, 40],
#          [73, 51, 40],
#          ...,
#          [56, 21, 25],
#          [55, 19, 21],
#          [51, 15, 17]],
#
#         [[71, 47, 37],
#          [71, 47, 37],
#          [70, 48, 37],
#          ...,
#          [55, 20, 24],
#          [52, 16, 18],
#          [47, 11, 13]],
#
#         [[75, 51, 41],
#          [73, 49, 39],
#          [70, 48, 37],
#          ...,
#          [56, 20, 24],
#          [52, 16, 20],
#          [48, 12, 16]],
#
#         ...,
#
#         [[40, 43, 48],
#          [41, 44, 49],
#          [40, 43, 48],
#          ...,
#          [35, 49, 49],
#          [35, 49, 49],
#          [36, 50, 50]],
#
#         [[39, 42, 49],
#          [39, 42, 49],
#          [39, 42, 49],
#          ...,
#          [35, 49, 50],
#          [35, 49, 50],
#          [36, 50, 51]],
#
#         [[38, 41, 48],
#          [38, 41, 48],
#          [38, 41, 48],
#          ...,
#          [35, 49, 50],
#          [35, 49, 50],
#          [36, 50, 51]]], dtype=uint8)]

# %%
df=results.crop()
# Out:
# Saved 1 image to runs\detect\exp
# Saved results to runs\detect\exp

# %%
len(df)
# Out:
# 4

# %%
df[0]
# Out:
# {'box': [tensor(978.98981),
#   tensor(313.57947),
#   tensor(1025.30286),
#   tensor(415.52618)],
#  'conf': tensor(0.26152),
#  'cls': tensor(27.),
#  'label': 'tie 0.26',
#  'im': array([[[168, 175, 154],
#          [178, 184, 165],
#          [186, 192, 173],
#          ...,
#          [134, 219,  61],
#          [134, 219,  61],
#          [134, 219,  61]],
#
#         [[162, 171, 150],
#          [169, 178, 158],
#          [173, 182, 162],
#          ...,
#          [134, 219,  61],
#          [134, 219,  61],
#          [134, 219,  61]],
#
#         [[159, 168, 147],
#          [163, 174, 154],
#          [169, 178, 157],
#          ...,
#          [134, 219,  61],
#          [134, 219,  61],
#          [134, 219,  61]],
#
#         ...,
#
#         [[  9,  10,   6],
#          [ 18,  19,  15],
#          [ 26,  28,  22],
#          ...,
#          [237, 249, 255],
#          [235, 248, 255],
#          [231, 243, 255]],
#
#         [[  5,   6,   2],
#          [ 13,  14,  10],
#          [ 20,  21,  17],
#          ...,
#          [216, 231, 250],
#          [198, 212, 235],
#          [184, 199, 225]],
#
#         [[  4,   5,   1],
#          [ 10,  11,   9],
#          [ 15,  16,  12],
#          ...,
#          [174, 192, 221],
#          [148, 165, 198],
#          [134, 150, 187]]], dtype=uint8)}

# %% [markdown]
# # 4. Real Time Detections

# %%
# !pip install pyautogui
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
#      ---------------------------------------- 59.0/59.0 KB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Downloading pytweening-1.0.4.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyrect
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Pillow>=6.2.1 in c:\users\moham\desktop\faseeh\odbot\odbot\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.1.0)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36584 sha256=908eb2b5462cdd606da056e49c74f101f638cee696b62c5a531cdbf45378f466
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\54\04\f7\55704a9d374ed923785a4fdc0ef00151fa25306b3b93345532
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11081 sha256=889427ed59bb240f20e95381336c565dac7dd4c577eff7d791b57f171e7b65af
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\91\e3\04\184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for pyscreeze (pyproject.toml): started
#   Building wheel for pyscreeze (pyproject.toml): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13009 sha256=8e1fbbf08cfc7c4a144280594ecdf5a87ca0265d86fcaf2f4b1e7ef00ab75533
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\b1\b0\5c\9fb5beb2d6c708479a670e92f4ab3b54523a15c9cd4a46e24e
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=pytweening-1.0.4-py3-none-any.whl size=5825 sha256=f2e827330da02a8bf86e9ac9d215da31440450c455826fb5a4b6aae0c66ec7f7
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\a2\1b\69\dc477653ccc19228bf53af76c623e4e82e5dc1b6f78d5c4d35
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10906 sha256=2ac6656190f446a284df18e189b5dd5573d0cae45012a03dd1c99f0c3686bafc
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\d1\72\fb\35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pymsgbox (pyproject.toml): started
#   Building wheel for pymsgbox (pyproject.toml): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7406 sha256=87f0735aa843b7334c6d9f4e4e5024528982c0240d0971ec4c4ea96c12b78f56
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\91\28\0d\f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=9ce0e67c51a30e41f51ea3339c2f2d2b50211c896416326b1cc853fb0c54196c
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11166 sha256=d04846e0ff9b78dbe062f0c63da84d6e1ef7de0d566d43cec98b2244114dbb2d
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\1b\c1\cc\3d6515746ab138a303b6b5d38181399703488f8109b734e768
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: PyTweening, pyrect, pyperclip, pymsgbox, pyscreeze, pygetwindow, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.4 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.28

# %%
# Import some dependencies
import pyautogui
import cv2
import numpy as np

# %%
# Loop over the frames
while True: 
    # Take a screenshot 
    screen = pyautogui.screenshot()
    # Convert the output to a numpy array
    screen_array = np.array(screen)
    # Crop out the region we want - height, width, channels   
    cropped_region = screen_array[25:625, 1122:, :]
    # Convert the color channel order
    corrected_colors = cv2.cvtColor(cropped_region, cv2.COLOR_RGB2BGR)
    
    # Make detections 
    results = model(corrected_colors)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))

    # Cv2.waitkey
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
# Close down the frame
cv2.destroyAllWindows()

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
# labels = ['left_obs', 'right_obs', 'timberman']
number_imgs = 100

# %%
# Loop over the frames
for img_num in range(number_imgs): 
    print('Collecting image number {}'.format(img_num))

    screen = pyautogui.screenshot()
    screen_array = np.array(screen)
    cropped_region = screen_array[25:625, 1122:, :]
    
    imgname = os.path.join(IMAGES_PATH, str(uuid.uuid1())+'.jpg')
    corrected_colors = cv2.cvtColor(cropped_region, cv2.COLOR_RGB2BGR)
    cv2.imwrite(imgname, corrected_colors)

    results = model(corrected_colors)
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    # 2 second delay between captures
    time.sleep(0.2)

    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# Collecting image number 0
# Collecting image number 1
# Collecting image number 2
# Collecting image number 3
# Collecting image number 4
# Collecting image number 5
# Collecting image number 6
# Collecting image number 7
# Collecting image number 8
# Collecting image number 9
# Collecting image number 10
# Collecting image number 11
# Collecting image number 12
# Collecting image number 13
# Collecting image number 14
# Collecting image number 15
# Collecting image number 16
# Collecting image number 17
# Collecting image number 18
# Collecting image number 19
# Collecting image number 20
# Collecting image number 21
# Collecting image number 22
# Collecting image number 23
# Collecting image number 24
# Collecting image number 25
# Collecting image number 26
# Collecting image number 27
# Collecting image number 28
# Collecting image number 29
# Collecting image number 30
# Collecting image number 31
# Collecting image number 32
# Collecting image number 33
# Collecting image number 34
# Collecting image number 35
# Collecting image number 36
# Collecting image number 37
# Collecting image number 38
# Collecting image number 39
# Collecting image number 40
# Collecting image number 41
# Collecting image number 42
# Collecting image number 43
# Collecting image number 44
# Collecting image number 45
# Collecting image number 46
# Collecting image number 47
# Collecting image number 48
# Collecting image number 49
# Collecting image number 50
# Collecting image number 51
# Collecting image number 52
# Collecting image number 53
# Collecting image number 54
# Collecting image number 55
# Collecting image number 56
# Collecting image number 57
# Collecting image number 58
# Collecting image number 59
# Collecting image number 60
# Collecting image number 61
# Collecting image number 62
# Collecting image number 63
# Collecting image number 64
# Collecting image number 65
# Collecting image number 66
# Collecting image number 67
# Collecting image number 68
# Collecting image number 69
# Collecting image number 70
# Collecting image number 71
# Collecting image number 72
# Collecting image number 73
# Collecting image number 74
# Collecting image number 75
# Collecting image number 76
# Collecting image number 77
# Collecting image number 78
# Collecting image number 79
# Collecting image number 80
# Collecting image number 81
# Collecting image number 82
# Collecting image number 83
# Collecting image number 84
# Collecting image number 85
# Collecting image number 86
# Collecting image number 87
# Collecting image number 88
# Collecting image number 89
# Collecting image number 90
# Collecting image number 91
# Collecting image number 92
# Collecting image number 93
# Collecting image number 94
# Collecting image number 95
# Collecting image number 96
# Collecting image number 97
# Collecting image number 98
# Collecting image number 99

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Collecting pyqt5
#   Downloading PyQt5-5.15.6-cp36-abi3-win_amd64.whl (6.7 MB)
#      ---------------------------------------- 6.7/6.7 MB 1.4 MB/s eta 0:00:00
# Collecting lxml
#   Downloading lxml-4.8.0-cp38-cp38-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 864.7 kB/s eta 0:00:00
# Collecting PyQt5-sip<13,>=12.8
#   Downloading PyQt5_sip-12.10.1-cp38-cp38-win_amd64.whl (77 kB)
#      ---------------------------------------- 77.5/77.5 KB 1.1 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#      ---------------------------------------- 50.1/50.1 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, lxml, pyqt5
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.10.1 lxml-4.8.0 pyqt5-5.15.6

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 2000 --data dataset.yml --hyp hyp.scratch.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=hyp.scratch.yaml, epochs=2000, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5  v6.1-177-gd059d1d torch 1.11.0+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=19
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     64728  models.yolo.Detect                      [19, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7070872 parameters, 7070872 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
#    18/1999        0G   0.09519   0.02181   0.02169        76       320:  40%|####      | 2/5 [00:06<00:10,  3.38s/it]
#    18/1999        0G   0.09585   0.02129   0.02179        63       320:  40%|####      | 2/5 [00:10<00:10,  3.38s/it]
#    18/1999        0G   0.09585   0.02129   0.02179        63       320:  60%|######    | 3/5 [00:10<00:06,  3.41s/it]
#    18/1999        0G   0.09611   0.02067   0.02169        60       320:  60%|######    | 3/5 [00:13<00:06,  3.41s/it]
#    18/1999        0G   0.09611   0.02067   0.02169        60       320:  80%|########  | 4/5 [00:13<00:03,  3.37s/it]
#    18/1999        0G   0.09568     0.021   0.02198        31       320:  80%|########  | 4/5 [00:14<00:03,  3.37s/it]
#    18/1999        0G   0.09568     0.021   0.02198        31       320: 100%|##########| 5/5 [00:14<00:00,  2.64s/it]
#    18/1999        0G   0.09568     0.021   0.02198        31       320: 100%|##########| 5/5 [00:14<00:00,  2.97s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/3 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  33%|###3      | 1/3 [00:02<00:05,  2.81s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  67%|######6   | 2/3 [00:05<00:02,  2.87s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 3/3 [00:06<00:00,  1.81s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 3/3 [00:06<00:00,  2.09s/it]
#                  all         70        146      0.558      0.181      0.067     0.0154
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#    19/1999        0G   0.09675   0.01987   0.02239        62       320:   0%|          | 0/5 [00:03<?, ?it/s]
#    19/1999        0G   0.09675   0.01987   0.02239        62       320:  20%|##        | 1/5 [00:03<00:13,  3.40s/it]
#    19/1999        0G   0.09631     0.019   0.02138        61       320:  20%|##        | 1/5 [00:06<00:13,  3.40s/it]
#    19/1999        0G   0.09631     0.019   0.02138        61       320:  40%|####      | 2/5 [00:06<00:10,  3.43s/it]
#    19/1999        0G   0.09651   0.01892   0.02129        65       320:  40%|####      | 2/5 [00:10<00:10,  3.43s/it]
#    19/1999        0G   0.09651   0.01892   0.02129        65       320:  60%|######    | 3/5 [00:10<00:06,  3.36s/it]
# ...
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'
# Exception ignored in: <function StorageWeakRef.__del__ at 0x0000019BFDF7C550>
# Traceback (most recent call last):
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\multiprocessing\reductions.py", line 36, in __del__
#   File "C:\Users\moham\Desktop\Faseeh\ODBot\odbot\lib\site-packages\torch\storage.py", line 520, in _free_weak_ref
# AttributeError: 'NoneType' object has no attribute '_free_weak_ref'

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('yolov5', 'custom', source='local', path='yolov5/runs/train/exp2/weights/best.pt')
# Out:
# YOLOv5  v6.1-177-gd059d1d torch 1.11.0+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7061368 parameters, 0 gradients, 16.0 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', '0a3c1ebc-d0e7-11ec-9b7b-7c5079e62b6a.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 600x798 1 left_obs, 1 timberman, 1 right_obs
# Speed: 25.9ms pre-process, 219.4ms inference, 2.0ms NMS per image at shape (1, 3, 512, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
# Loop over the frames
while True: 
    # Take a screenshot 
    screen = pyautogui.screenshot()
    # Convert the output to a numpy array
    screen_array = np.array(screen)
    # Crop out the region we want - height, width, channels   
    cropped_region = screen_array[25:625, 1122:, :]
    # Convert the color channel order
    corrected_colors = cv2.cvtColor(cropped_region, cv2.COLOR_RGB2BGR)
    
    # Make detections -Custom Model
    results = model(corrected_colors)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))

    # Cv2.waitkey
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
# Close down the frame
cv2.destroyAllWindows()
